# %%
from flashcast import *

# %%
import pandas as pd
import numpy as np

# Generate synthetic time series data
np.random.seed(42)
dates = pd.date_range("2020-01-01", periods=500)
price_data = np.sin(np.linspace(0, 50, 500)) + np.random.normal(0, 0.1, 500)  # A sine wave with noise
df = pd.DataFrame(data={"Date": dates, "Price": price_data}).set_index("Date")
df
# Out:
#                Price
# Date
# 2020-01-01  0.049671
# 2020-01-02  0.086206
# 2020-01-03  0.263831
# 2020-01-04  0.448397
# 2020-01-05  0.366741
# ...              ...
# 2021-05-10 -0.564178
# 2021-05-11 -0.640055
# 2021-05-12 -0.468246
# 2021-05-13 -0.445149
# 2021-05-14 -0.400655
#
# [500 rows x 1 columns]

# %%
# Initialize the LSTM model
n_features = 1  # Number of features (in this case, just 'Price')
model = Magic(n_features=n_features, num_layers=3, hidden_size=250)

# %%
# These settings are not high enough to be accurate, just reasonable
future = predict_futures(
    df, 
    model,
    epochs=100, 
    forecast_len=10,
    sliding_window_divisor=4, 
    ignore_hols=[["UK", "US"]], 
    lookbacks=TRADING_MONTH, # 21
    verbose = True)[0]
# Out:
# Running model 0...
# Loss at epoch 20: 0.001982147805392742
# Loss at epoch 40: 0.002813133876770735
# Loss at epoch 60: 0.00382186658680439
# Loss at epoch 80: 0.002076179487630725
# Loss at epoch 100: 0.001934847910888493
# Forecast [1/10]: tensor([[[0.4229]]])
# Forecast [2/10]: tensor([[[0.4556]]])
# Forecast [3/10]: tensor([[[0.4938]]])
# Forecast [4/10]: tensor([[[0.5348]]])
# Forecast [5/10]: tensor([[[0.5770]]])
# Forecast [6/10]: tensor([[[0.6194]]])
# Forecast [7/10]: tensor([[[0.6615]]])
# Forecast [8/10]: tensor([[[0.7032]]])
# Forecast [9/10]: tensor([[[0.7440]]])
# Forecast [10/10]: tensor([[[0.7836]]])

# %%
quick_visuals((future, df))
